# %% [markdown]
# # SimpleHtml
#
# Kevin J. Walchko, 22 Dec 2016
#
# ----------
#
# Simplehtml is an easy way to dynamically generate an html page. We can use Jupyter Notebooks to experiement with creating html. By using it's built in `HTML` class, we can easily display what we create.
#
# To use this, make sure you install the following:
#
# ```bash
# pip install simplehtml
# pip install loremipsum # random sentences and paragraphs for examples
# pip install mpld3 # for html plots of matplotlib
# pip install version_information # get version info for packages
# ```
#
# Now, some CSS changes seem to effect Jupyter Notebooks, so they either don't work well or at all. However, they do work when run in a real browser outside of the notebook.

# %%
from __future__ import print_function
from IPython.core.display import HTML  # render html in a cell
from simplehtml import HTML as HTML5   # generate html dyanically
from simplehtml import CSS             # change html look
from loremipsum import get_paragraph   # fake paragraphs
from matplotlib import pyplot as plt
import mpld3
from math import cos, sin, pi

# %%
# %reload_ext version_information
# %version_information simplehtml, loremipsum, matplotlib, mpld3
# Out:
# Software versions
# Python 2.7.12 64bit [GCC 4.2.1 Compatible Apple LLVM 8.0.0 (clang-800.0.38)]
# IPython 5.1.0
# OS Darwin 16.3.0 x86_64 i386 64bit
# simplehtml 0.2.0
# loremipsum 1.0.5
# matplotlib 1.5.3
# mpld3 0.3
# Fri Dec 23 00:29:24 2016 MST

# %%
dir(HTML5)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'clear',
#  'css',
#  'cssLink',
#  'div',
#  'find',
#  'footer',
#  'h1',
#  'h2',
#  'h3',
#  'hr',
#  'iframe',
#  'img',
#  'javascript',
#  'linuxFont',
#  'p',
#  'table',
#  'tooltip',
#  'write']

# %% [markdown]
# ## Simple Text
#
# Now we will just create a simple html page filled with random text and an image from the web.

# %%
html = HTML5()
html.img('https://botsofwesteros.files.wordpress.com/2012/06/banner.jpg', width='100%')
# html.css('h1 {text-align: center;}')  # changes jupyter header locations
# html.css('body {background-color: red;}')  # no effect
html.h1('header 1')
html.hr()
html.h2('header 2')
html.img('http://cdn.macrumors.com/images-new/logo.png', width=200)
html.p(get_paragraph())
html.p(get_paragraph())
html.h3('header 3')
html.img('https://upload.wikimedia.org/wikipedia/en/a/a6/Bender_Rodriguez.png', width='100px')
html.p(get_paragraph())
html.p(get_paragraph())
# html.iframe('http://www.macrumors.com/', width=600, height=100)
html.hr()
html.footer('my footer')

HTML(str(html))
# Out:
# <!DOCTYPE html><html><head><style></style></head><body><img src="https://botsofwesteros.files.wordpress.com/2012/06/banner.jpg" alt="img" width="100%"><h1>header 1</h1><hr><h2>header 2</h2><img src="http://cdn.macrumors.com/images-new/logo.png" alt="img" width="200"><p>Class fusce tristique eros nam. Nulla justo vitae non sapien interdum phasellus mi hendrerit morbi augue nunc. Lorem proin vel vestibulum parturient ve odio vehicula fusce. Curae augue sapien sociis lorem mollis cras erat ve sociosqu quisque orci. Massa porta nullam sociis ipsum parturient suspendisse tempus in arcu ut. Massa velit nisl a arcu ve massa eu. Lorem morbi integer lectus nulla at consectetuer. Porta class senectus vitae cursus fusce curae nec. Ipsum porta tortor class netus taciti. Justo netus senectus adipiscing tellus at eros at risus. Lorem dolor etiam luctus. Curae dolor congue dui sociis proin porttitor imperdiet amet est metus vulputate hymenaeos porta id platea interdum diam nec. Etiam massa nostra dictum ultricies. Dolor purus interdum class in quis sociosqu sem rhoncus ut. Netus dolor rutrum egestas erat. Magna morbi faucibus ipsum auctor ornare porta viverra. Vitae justo dictum quam hendrerit penatibus adipiscing leo felis viverra. Dolor netus enim pharetra per mollis inceptos netus mi tellus porttitor iaculis. Class morbi potenti. Donec etiam.</p><p>Risus dolor natoque dictum per cursus arcu tortor laoreet pede urna nibh inceptos euismod pretium sociis. Dolor vitae. Proin dolor non. Massa lacus dictum auctor ridiculus. Proin fusce. Dolor metus. Purus velit lobortis dui quisque sociosqu et nullam. Massa fusce. Fames neque enim dis morbi commodo erat nascetur. Donec purus fames quam sodales ac facilisis parturient iaculis. Porta ipsum habitant vestibulum aliquam enim. Ipsum donec egestas sapien et erat commodo neque nisl eget. Morbi augue primis habitant risus fames aptent aenean sed adipiscing netus vivamus. Netus fusce lorem aliquam luctus lectus laoreet enim pede. Lacus porta ultrices duis nullam praesent. Ipsum fusce sapien velit sapien taciti vitae cum. Proin neque cursus ligula.</p><h3>header 3</h3><img src="https://upload.wikimedia.org/wikipedia/en/a/a6/Bender_Rodriguez.png" alt="img" width="100px"><p>Felis metus nulla sem risus consequat. Dolor magna integer. Nulla fusce erat. Morbi netus. Lacus curae congue. Lacus porta. Fusce netus duis nam amet morbi pulvinar parturient ultricies. Nulla felis enim arcu molestie tellus lacus. Velit netus enim non massa nulla sed netus. Velit augue pharetra magna justo. Felis risus enim commodo curabitur vehicula. Etiam fusce. Risus purus.</p><p>Velit felis nonummy pede in. Fames risus scelerisque elit nibh dictumst. Proin fames cras quis diam nascetur vulputate dis. Vitae augue magnis sociosqu dapibus magna fames aenean ipsum facilisis. Donec fusce libero mattis ultricies adipiscing nibh. Nulla augue convallis maecenas nascetur mollis diam id consectetuer. Velit lorem dictum gravida erat ac fusce primis montes torquent aliquam pede. Porta proin cubilia cursus sociis aliquet aliquam dolor eget aptent eu. Felis ipsum erat id fusce litora mi senectus cursus quis pede. Lacus purus a cubilia sociis litora cum ad. Felis vitae metus nostra morbi phasellus ridiculus. Proin morbi.</p><hr><footer>my footer</footer></body></html>

# %% [markdown]
# ## Tables
#
# We can also create a table from `json` data.

# %%
data = {
    'header': ['Param', 'Something'],
    'data': [
        ['OS', 'Linux Debian Jessie'],
        ['cpu', 'ARM'],
        ['load', '[1.0, 3.0]'],
        ['ram [GB]', 512],
        ['uptime', '3 days'],
        ['storage [GB]', 3],
        ['host', 'bob.local'],
        ['IPv4', '127.0.0.1'],
        ['MAC', '123456'],
        ['Bluetooth', 'Up']
    ]
}

html = HTML5()
html.css(CSS.cssTable())  # make the table look pretty
html.hr()
html.table(data)
HTML(str(html))
# Out:
# <!DOCTYPE html><html><head><style>
# 		table {
# 			font-family: arial, sans-serif;
# 			border-collapse: collapse;
# 			width: 100%;
# 			}
# 		td, th {
# 			border: 1px solid #dddddd;
# 			text-align: left;
# 			padding: 8px;
# 		}
# 		tr:nth-child(even) {
# 			background-color: #dddddd;
# 		}</style></head><body><hr><table><tr><th>Param</th><th>Something</th></tr><tr><td>OS</td><td>Linux Debian Jessie</td></tr><tr><td>cpu</td><td>ARM</td></tr><tr><td>load</td><td>[1.0, 3.0]</td></tr><tr><td>ram [GB]</td><td>512</td></tr><tr><td>uptime</td><td>3 days</td></tr><tr><td>storage [GB]</td><td>3</td></tr><tr><td>host</td><td>bob.local</td></tr><tr><td>IPv4</td><td>127.0.0.1</td></tr><tr><td>MAC</td><td>123456</td></tr><tr><td>Bluetooth</td><td>Up</td></tr></table></body></html>

# %% [markdown]
# ## Charts
#
# Now, we can use [mpld3](http://mpld3.github.io/) to embed `matplotlib` charts into an html page and make them interactive. Let's load up the libraries and create a few.

# %%
# make some data to plot
x = []
y = []
y2 = []
y3 = []

for i in range(0, 600):
    xx = float(i)
    yy = 5.0*cos(2.0*pi*i/200)
    yy2 = yy*sin(2.0*pi*i/300)
    yy3 = 3.5*cos(2.0*pi*i/100)+2.0*sin(2.0*pi*i/300)
    x.append(xx)
    y.append(yy)
    y2.append(yy2)
    y3.append(yy3)

# %%
# Now setup a scatter plot
fig, ax = plt.subplots()
scatter = ax.plot(x, y, x, y2, x, y3)
ax.grid(True)
ax.set_title("3 lines to plot", size=20)

# turn the plots into html and embed in a web page
html = mpld3.fig_to_html(fig);
HTML(html)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el2490146046025763699350926"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el2490146046025763699350926", {"axes": [{"xlim": [0.0, 600.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#000000", "text": "3 lines to plot", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 20.0, "position": [0.49999999999999994, 1.0224014336917562], "rotation": -0.0, "id": "el249014608622544"}], "zoomable": true, "images": [], "xdomain": [0.0, 600.0], "ylim": [-6.0, 6.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 1.0, "dasharray": "2,2", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 1.0, "dasharray": "2,2", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"drawstyle": "default", "color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data01", "id": "el249014604600848"}, {"drawstyle": "default", "color": "#007F00", "yindex": 2, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data01", "id": "el249014607904272"}, {"drawstyle": "default", "color": "#FF0000", "yindex": 3, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data01", "id": "el249014605933456"}], "markers": [], "id": "el249014603468176", "ydomain": [-6.0, 6.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "height": 288.0, "width": 432.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "data": {"data01": [[0.0, 5.0, 0.0, 3.5], [1.0, 4.997532801828658, 0.1046604303167451, 3.5349783892656643], [2.0, 4.990133642141358, 0.20896510846074126, 3.556152762059072], [3.0, 4.9778098230154, 0.31255926490525643, 3.5635864166090374], [4.0, 4.9605735065723895, 0.41509009272139924, 3.55739675061484], [5.0, 4.938441702975689, 0.5162077221489423, 3.5377547335683444], [6.0, 4.911436253643443, 0.6155661871140852, 3.5048841677374885], [7.0, 4.879583809693737, 0.7128243810441716, 3.4590607407558913], [8.0, 4.842915805643155, 0.8076469993587116, 3.4006108735857272], [9.0, 4.801468428384715, 0.899705466052581, 3.329910368428502], [10.0, 4.755282581475767, 0.9886788418308661, 3.247382861947835], [11.0, 4.704403844771127, 1.0742547113054008, 3.1534980899365737], [12.0, 4.648882429441257, 1.1561300468204223, 3.04876997030465], [13.0, 4.588773128419906, 1.2340120465388327, 2.933754511980942], [14.0, 4.524135262330098, 1.3076189444911168, 2.809047558009357], [15.0, 4.455032620941839, 1.3766807903657916, 2.675282371773551], [16
2.22647662584711], [19.0, 4.1354028713728095, 1.6025330689157447, 2.0634671073005793], [20.0, 4.045084971874737, 1.645284282416698, 1.8950327664639164], [21.0, 3.950775061878452, 1.6821582069795633, 1.721973188207137], [22.0, 3.852566213878946, 1.7129864688298626, 1.5451049594198913], [23.0, 3.750555348152298, 1.7376174222965521, 1.365258387714789], [24.0, 3.644843137107058, 1.7559165728257473, 1.183274166556028], [25.0, 3.5355339059327378, 1.7677669529663689, 1.0000000000000002], [26.0, 3.4227355296434436, 1.7730694502963498, 0.8162872003936634], [27.0, 3.3065593266182596, 1.7717430863897714, 0.6329872724829289], [28.0, 3.1871199487434487, 1.7637252460595045, 0.4509484974366521], [29.0, 3.0645352682648825, 1.7489718562462178, 0.2710125302918712], [30.0, 2.9389262614623664, 1.7274575140626318, 0.09401102427263108], [31.0, 2.8104168892606536, ...

# %%
def make_donut(sizes, text, colors, labels):
    col = [[i / 255 for i in c] for c in colors]
    fig, ax = plt.subplots();
    ax.axis('equal');
    width = 0.35
    kwargs = dict(colors=col, startangle=180)
    outside = ax.pie(sizes, radius=1, pctdistance=1-width/2, autopct='%1.1f%%', labels=labels, **kwargs)[0];
    plt.setp(outside, width=width, edgecolor='white');

    kwargs = dict(size=20, fontweight='bold', va='center')
    ax.text(0, 0, text, ha='center', **kwargs);
    return mpld3.fig_to_html(fig);


c1 = (226, 33, 7)
# c1 = (80, 220, 80)
c2 = (60, 121, 189)

donut = make_donut([5, 95], "donut", [c1, c2], ['Free', 'Load']);
html = HTML5()
html.h1('uuum, donuts!')
html.p(donut)
HTML(str(html))
# Out:
# <!DOCTYPE html><html><head><style></style></head><body><h1>uuum, donuts!</h1><p>
#
# <style>
#
# </style>
#
# <div id="fig_el2490146058670887114071870"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el2490146058670887114071870", {"axes": [{"xlim": [-1.875, 1.875], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "central", "h_anchor": "end", "color": "#000000", "text": "Free", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-1.0864571742518743, -0.17207791408729045], "rotation": -0.0, "id": "el249014611259600"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "5.0%", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-0.81484288068890554, -0.12905843556546781], "rotation": -0.0, "id": "el249014611313872"}, {"v_baseline": "central", "h_anchor": "start", "color": "#000000", "text": "Load", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [1.086457180293535, 0.17207787594174187], "rotation": -0.0, "id": "el249014611316432"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "95.0%", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.81484288522015103, 0.12905840695630638], "rotation": -0.0, "id": "el249014611317392"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "donut", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 20.0, "position": [0, 0], "rotation": -0.0, "id": "el249014595478928"}], "zoomable": true, "images": [], "xdomain": [-1.875, 1.875], "ylim": [-1.25, 1.25], "paths": [{"edgecolor": "#FFFFFF", "facecolor": "#000000", "edgewidth": 1.0, "pathcodes": ["M", "C", "C", "L", "C", "C", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data01", "id": "el249014611258192"}, {"edgecolor": "#FFFFFF", "facecolor": "#000000", "edgewidth": 1.0, "pathcodes": ["M", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "L", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data02", "id": "el249014611314960"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "visible": true, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "visible": true, "fontsize": null, "position": "left", "nticks": 0, "tickvalues": []}], "lines": [], "markers": [], "id": "el249014605868496", "ydomain": [-1.25, 1.25], "collections": [], "xscale": "linear", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "height": 288.0, "width": 432.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "data": {"data02": [[-0.9510565148485406, -0.3090169988271645], [-0.9125177197133572, -0.42762721226797756], [-0.8521282782924692, -0.5379879355499145], [-0.7730104533627367, -0.6343932841636458], [-0.6938926284330041, -0.7307986327773771], [-0.5974338510766017, -0.8115580170577626], [-0.48862124558140335, -0.8724960047853961], [-0.37980864008620496, -0.9334339925130296], [-0.26055037305222223, -0.9734819590343186], [-0.1370123509563474, -0.990569339160775], [-0.013474328860472576, -1.0076567192872317], [0.11217705290108057, -1.0014838642061963], [0.23344535019992912, -0.9723699236761864], [0.35471364749877765, -0.9432559831461764], [0.46947226743244663, -0.8917115069206991], [0.5717879448653069, -0.8204014542324438], [0.6741036222981672, -0.7490914015441885], [0.7621821224773021, -0.6592662843183638], [0.8314695992984852, -0.5555702524815529], [0.9007570761196683, -0.45187422064474203], [0.9500384860824929, -0.33612571520940177], [0.9767658753013507, -0.21430918050047745], [1.0034932645202086, -0.09249264579155314], [1.0071979344359496, 0.03325571125240388], [0.9876883457213953, 0.15643443267431104], [0.9681787570068409, 0.27 ...

# %% [markdown]
# I am having trouble setting up the color of the donut for some reason, but it works outside of the notebook no problem.
#
# Now let's take a look at the raw html code ... it isn't formated nicely for human reading.

# %%
print(html)
# Out:
# <!DOCTYPE html><html><head><style></style></head><body><h1>uuum, donuts!</h1><p>
#
# <style>
#
# </style>
#
# <div id="fig_el2490146058670887114071870"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el2490146058670887114071870", {"axes": [{"xlim": [-1.875, 1.875], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "central", "h_anchor": "end", "color": "#000000", "text": "Free", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-1.0864571742518743, -0.17207791408729045], "rotation": -0.0, "id": "el249014611259600"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "5.0%", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-0.81484288068890554, -0.12905843556546781], "rotation": -0.0, "id": "el249014611313872"}, {"v_baseline": "central", "h_anchor": "start", "color": "#000000", "text": "Load", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [1.086457180293535, 0.17207787594174187], "rotation": -0.0, "id": "el249014611316432"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "95.0%", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.81484288522015103, 0.12905840695630638], "rotation": -0.0, "id": "el249014611317392"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "donut", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 20.0, "position": [0, 0], "rotation": -0.0, "id": "el249014595478928"}], "zoomable": true, "images": [], "xdomain": [-1.875, 1.875], "ylim": [-1.25, 1.25], "paths": [{"edgecolor": "#FFFFFF", "facecolor": "#000000", "edgewidth": 1.0, "pathcodes": ["M", "C", "C", "L", "C", "C", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data01", "id": "el249014611258192"}, {"edgecolor": "#FFFFFF", "facecolor": "#000000", "edgewidth": 1.0, "pathcodes": ["M", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "L", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data02", "id": "el249014611314960"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "visible": true, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "visible": true, "fontsize": null, "position": "left", "nticks": 0, "tickvalues": []}], "lines": [], "markers": [], "id": "el249014605868496", "ydomain": [-1.25, 1.25], "collections": [], "xscale": "linear", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "height": 288.0, "width": 432.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "data": {"
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#                  mpld3.draw_figure("fig_el2490146058670887114071870", {"axes": [{"xlim": [-1.875, 1.875], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "central", "h_anchor": "end", "color": "#000000", "text": "Free", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-1.0864571742518743, -0.17207791408729045], "rotation": -0.0, "id": "el249014611259600"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "5.0%", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [-0.81484288068890554, -0.12905843556546781], "rotation": -0.0, "id": "el249014611313872"}, {"v_baseline": "central", "h_anchor": "start", "color": "#000000", "text": "Load", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [1.086457180293535, 0.17207787594174187], "rotation": -0.0, "id": "el249014611316432"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "95.0%", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.81484288522015103, 0.12905840695630638], "rotation": -0.0, "id": "el249014611317392"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "donut", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 20.0, "position": [0, 0], "rotation": -0.0, "id": "el249014595478928"}], "zoomable": true, "images": [], "xdomain": [-1.875, 1.875], "ylim": [-1.25, 1.25], "paths": [{"edgecolor": "#FFFFFF", "facecolor": "#000000", "edgewidth": 1.0, "pathcodes": ["M", "C", "C", "L", "C", "C", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data01", "id": "el249014611258192"}, {"edgecolor": "#FFFFFF", "facecolor": "#000000", "edgewidth": 1.0, "pathcodes": ["M", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "L", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "C", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data02", "id": "el249014611314960"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "visible": true, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "visible": true, "fontsize": null, "position": "left", "nticks": 0, "tickvalues": []}], "lines": [], "markers": [], "id": "el249014605868496", "ydomain": [-1.25, 1.25], "collections": [], "xscale": "linear", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "height": 288.0, "width": 432.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "data": {"data02": [[-0.9510565148485406, -0.3090169988271645], [-0.9125177197133572, -0.42762721226797756], [-0.8521282782924692, -0.5379879355499145], [-0.7730104533627367, -0.6343932841636458], [-0.6938926284330041, -0.7307986327773771], [-0.5974338510766017, -0.8115580170577626], [-0.48862124558140335, -0.8724960047853961], [-0.37980864008620496, -0.9334339925130296], [-0.26055037305222223, -0.9734819590343186], [-0.1370123509563474, -0.990569339160775], [-0.013474328860472576, -1.0076567192872317], [0.11217705290108057, -1.0014838642061963], [0.23344535019992912, -0.9723699236761864], [0.35471364749877765, -0.9432559831461764], [0.46947226743244663, -0.8917115069206991], [0.5717879448653069, -0.8204014542324438], [0.6741036222981672, -0.7490914015441885], [0.7621821224773021, -0.6592662843183638], [0.8314695992984852, -0.5555702524815529], [0.9007570761196683, -0.45187422064474203], [0.9500384860824929, -0.33612571520940177], [0.9767658753013507, -0.21430918050047745], [1.0034932645202086, -0.09249264579155314], [1.0071979344359496, 0.03325571125240388], [0.9876883457213953, 0.15643443267431104], [0.968178757006 ...
#             })
#          });
# }
# </script></p></body></html>

# %% [markdown]
# Some useful things in `mpld3`:
#
# * `mpld3.save_html(fig, filename)` saves the figure to *filename*
# * `mpld3.display(fig)` draw the plot in jupyter inline
# * `mpld3.show(fig)`, launches an http server and serves up a webpage showing the plot ... **don't use this in jupyter**

# %% [markdown]
# -----------
#
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>.
